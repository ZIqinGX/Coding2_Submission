# %% [markdown]
# This is my Python Challenge

# %% [markdown]
# # Instruction to whom is watching this notebook:
#
# ### 1.Try to solve the following four challenges by python program
# ### 2.Print the output
# ### 3.Connect four outputs and getting the result

# %% [markdown]
# #### No.1
#
# (1)Write a python program that sorts this list from short to long on their length.If there are words has same letter, arrange by alphabetical order.
# (2)Use python program to find the 7th word of new sequence
#
# Word List:
# [anticipate education her bee life cat am moon fish bicycle espresso egg library diamond ]

# %%
#My Answer:
seq = ['anticipate', 'education', ' her', 'bee', 'life', 'cat','am','moon','fish','bicycle','espresso','egg','library',' diamond']
sorted_seq = sorted(seq, key=lambda x: (len(x), x), reverse=False)

element = sorted_seq[6]
print(element)
# Out:
# life

# %% [markdown]
# #### No.2
# (1)Transform these letters and numbers into a sequence of 20 rows and 31 columns:
#
# coconutcta4gytewistwuqrtrawtvp
# rawtvpadkeetdjwdveakeefrawtvpri
# sthufwadidwtdjwdveakeeftuicew83
# juicewadidwtuicewadidwtw4w2rlef
# jwterberreiwwrappslevqnejefewgy
# 2oev24ytewistwuicewadidwtykiris
# thufmxnalefjwgrreiwwrappslevqne
# coconutcta4gytewistwuqrtrawtvp
# rawtvpadkeetdjwdveakeefrawtvpri
# sthufwadidwtdjwdveakeeftuicew83
# juicewadidwtuicewadidwtw4w2rlef
# jwterberreiwwrappslevqnejefewgy
# 2oev24ytewistwuicewadidwtykiris
# thufmxnalefjwgrreiwwrappslevqne
# cewadidwtuicewadidwtw4w2rlefsth
# jwterberreiwwrappslevqnejefewgy
# 2oev24ytewistwuicewadidwtykiris
# thufmxnalefjwgrreiwwrappslevqne
# coconutcta4gytewistwuqrtrawtvp
# rawtvpadkeetdjwdveakeefrawtvpri
#
# (2)Find letters in row 8, column 16 and row 6, column 11 of this sequence and print them

# %%
#Answer
s = 'coconutcta4gytewistwuqrtrawtvp' \
    'rawtvpadkeetdjwdveakeefrawtvpri' \
    'sthufwadidwtdjwdveakeeftuicew83' \
    'juicewadidwtuicewadidwtw4w2rlef' \
    'jwterberreiwwrappslevqnejefewgy' \
    '2oev24ytewistwuicewadidwtykiris' \
    'thufmxnalefjwgrreiwwrappslevqne' \
    'coconutcta4gytewistwuqrtrawtvp' \
    'rawtvpadkeetdjwdveakeefrawtvpri' \
    'sthufwadidwtdjwdveakeeftuicew83' \
    'juicewadidwtuicewadidwtw4w2rlef' \
    'jwterberreiwwrappslevqnejefewgy' \
    '2oev24ytewistwuicewadidwtykiris' \
    'thufmxnalefjwgrreiwwrappslevqne' \
    'cewadidwtuicewadidwtw4w2rlefsth' \
    'jwterberreiwwrappslevqnejefewgy' \
    '2oev24ytewistwuicewadidwtykiris' \
    'thufmxnalefjwgrreiwwrappslevqne' \
    'coconutcta4gytewistwuqrtrawtvp'

lines = [s[i:i+31] for i in range(0, len(s), 31)]
#for line in lines:
    #print(line)

letter1 = s[7*31 + 15]
letter2= s[5*31+10]
print(letter1)
print(letter2)
# Out:
# i
# s

# %% [markdown]
# #### No.3
# ![Challenge3.jpg](attachment:Challenge3.jpg)

# %%
#Answer

asc = 97
l1=chr(asc)
print(l1)

asc = 98
l2=chr(asc)
print(l2)

asc = 111
l3=chr(asc)
print(l3)

asc = 117
l4=chr(asc)
print(l4)

asc = 116
l5=chr(asc)
print(l5)
# Out:
# a
# b
# o
# u
# t

# %% [markdown]
# #### No.4
# ![Challenge4.jpg](attachment:Challenge4.jpg)

# %%
stack1 = ['s', 't', 'n', 'e', 'm', 'o', 'm']

# %%
stack2 = []

# %%
while (len(stack1) != 0):
    stack2.append(stack1.pop())

# %%
print(''.join(stack2))
# Out:
# moments

# %% [markdown]
# ### Now Since you solve all the quetstions, the final sentence is : life is about moments
